# %% [markdown]
# # why we separate data modelling into three levels while the database gonna be physical model?

# %% [raw]
# When building a database, we don’t directly jump into table creation. We need to understand the business, organize the data logically, and then convert it into the physical structure that a database understands.
# That is why data modeling is separated into three levels:
#     Conceptual Model
#     Logical Model
#     Physical Model
#
# Conceptual - Customer — places — Order
# Logical - CUSTOMER(cust_id, name, email), ORDER(order_id, order_date, cust_id FK)
# Physical - SQL: CREATE TABLE Customer (cust_id INT PRIMARY KEY, name VARCHAR(50), email VARCHAR(100));

# %% [markdown]
# ## Analogy

# %% [raw]
# Imagine building a house:
#
# Client discusses needs - Conceptual Model
# Architect draws blueprint - Logical Model
# Engineers construct building - Physical Model
#
# If you skip the blueprint and start building directly → the house will not match the client’s needs. SAME WITH DATABASES.

# %% [markdown]
# ## Note

# %% [raw]
# Full 3-level modelling - Large systems, enterprise projects
#
# Direct physical modelling - Small hobby projects, personal DBs

# %% [markdown]
# ## Summary

# %% [raw]
# The database becomes physical at the end, but we separate modeling to avoid mistakes early.
#
# Conceptual → Logical → Physical makes sure the system meets business needs, stays organized, and remains flexible and scalable.

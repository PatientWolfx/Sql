# %% [markdown]
# # Database

# %% [raw]
# A database is an organised collection of data stored electronically so that it can be easily accessed, managed and updated.
# Instead of keeping data in files or notebooks, databases store data in a structured and secure way.

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of a bank locker system:
#     Each locker -> table
#     Each drawer -> row
#     Each compartment -> column
#
# The bank(database) keeps everything safe, organised and easy to retrieve

# %% [raw]
# HOW-
# Database works using a Database Management System(DBMS).

# %% [raw]
# Basic workflow:
#
#     User / Application → DBMS → Database
#
# The DBMS:
#     Accepts queries(SQL)
#     Processes them
#     Return results

# %% [markdown]
# ## Example

# %% [raw]
# #SELECT all columns FROM table
#
# SELECT * FROM students;

# %% [markdown]
# ## When to Use

# %% [raw]
# Any application with structured data
#
# Business systems
#
# Analytics platforms

# %% [markdown]
# ## Database Components

# %% [raw]
# Tables
# Rows & columns

# %% [markdown]
# ## Database Types

# %% [raw]
# Relational Database Management Systems(RDBMS)
# NoSQL Databases
# In-Memory Databases

# %% [markdown]
# ## CRUD Operations

# %% [raw]
# Create -> INSERT
# Read -> SELECT
# Update -> UPDATE
# Delete -> DELETE

# %% [markdown]
# ## Alternatives

# %% [raw]
# File-Based Storage(CSV, Excel)
# Data Warehouse
# Cloud Databases

# %% [markdown]
# ## Real-World Examples

# %% [raw]
# Banking System:
#     Stores accounts, transactions
#     Ensures ACID properties

# %% [raw]
# Social Media App:
#     Stores users, posts, likes

# %% [markdown]
# ## Summary

# %% [raw]
# Database stores organized data
#
# Managed by DBMS
#
# Supports CRUD operations
#
# Types: RDBMS, NoSQL, In-memory
#
# Used in almost all applications
#
# Core topic for interviews

# %% [markdown]
# # Tables

# %% [raw]
# A table is a structured collection of data madeup of columns and rows.
#
# Columns -> Define data type and meaning.
# Rows -> Actual data records
#
# columns are defined while creating a table and the rows are the values we insert into the table.

# %% [raw]
# Each table represents one entity(like students, employees, orders) and keeps related data together in an organised way.

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of an Excel sheet:
#     Sheet -> Table
#     Columns -> Fiels(Name, Age, Salary)
#     Rows -> Records(One person's data)
#
# A database table works exactly like this, but with rules, security and performance optimizations

# %% [markdown]
# ## Example

# %% [raw]
# | id | name | salary |
# | -- | ---- | ------ |
# | 1  | John | 50000  |

# %% [markdown]
# ## HOW -

# %% [raw]
# Tables are created using DDL(Data Definition Language) commands.

# %% [markdown]
# ## Syntax

# %% [raw]
# CREATE TABLE table_name(column_name data_type);

# %% [markdown]
# ## Example(Query)

# %% [raw]
# #Sample Query
#
# CREATE TABLE employees (
#     emp_id INT,
#     emp_name VARCHAR(50),
#     salary INT
# );

# %% [markdown]
# ## When to Use

# %% [raw]
# Structured data
#
# Business applications
#
# Transactional systems

# %% [markdown]
# ## Real-World Example

# %% [raw]
# #Employee Management
#
# SELECT emp_name, salary FROM employees;

# %% [raw]
# #Banking System
#
# Tables: accounts, transactions, customers

# %% [markdown]
# ## Summary

# %% [raw]
# Table stores data in rows and columns
#
# Core structure of a database
#
# Created using CREATE TABLE
#
# Supports CRUD operations
#
# Can be altered or dropped
#
# Fundamental SQL interview topic

# %% [markdown]
# # Table Operations

# %% [markdown]
# ## Create table

# %% [raw]
# CREATE TABLE students (
#     id INT,
#     name VARCHAR(50),
#     age INT
# );

# %% [markdown]
# ## Insert data

# %% [raw]
# INSERT INTO students VALUES (1, 'Alice', 20);
#
# insert new values into tables.

# %% [markdown]
# ## Read data

# %% [raw]
# SELECT * FROM students;
#
# reads data.

# %% [markdown]
# ## Update data

# %% [raw]
# UPDATE students SET age= 22 WHERE id= 1;
#
# updates stored values in a table.

# %% [markdown]
# ## Delete data

# %% [raw]
# DELETE FROM students WHERE id = 1;
#
# deletes values from a table.

# %% [markdown]
# ## Alter table

# %% [raw]
# ALTER TABLE students ADD email VARCHAR(100); #adds new attribute
#
# ALTER TABLE students drop email VARCHAR(100); #removes existing attribute
#
# alter table attributes like adding new columns and removing existing columns.

# %% [markdown]
# ## Drop table

# %% [raw]
# DROP TABLE students;
#
# deletes table.

# %% [markdown]
# ## Truncate table

# %% [raw]
# TRUNCATE TABLE students;
#
# removes all records(rows) and keeps the structure(columns)

# %% [markdown]
# ## Rename table

# %% [raw]
# RENAME TABLE students TO studentdetails;
#
# renames table.

# %% [markdown]
# # Row

# %% [raw]
# A row represents one complete record in a database table.
# Each row contains values for every column defined in the table

# %% [markdown]
# ## Analogy

# %% [raw]
# If a table is a container, then a row is one item inside that container.
#
# Think of a student register:
#     Register -> Table
#     Columns -> Name, Rollno, Marks
#     One student's entry -> One row
# Each row tells the full story of one entity.

# %% [markdown]
# ## Example

# %% [raw]
# | id | name  | age |
# | -- | ----- | --- |
# | 1  | Alice | 20  |

# %% [markdown]
# ## HOW -

# %% [raw]
# Rows are added, read, updated, and deleted using DML commands.

# %% [markdown]
# ## Syntax

# %% [raw]
# # Insert a row into a table
#
# INSERT INTO table_name VALUES (...);

# %% [markdown]
# ## Example query

# %% [raw]
# # Sample query
# INSERT INTO students VALUES (1, 'Alice', 20);

# %% [markdown]
# ## When to Use

# %% [raw]
# Any structured data storage
#
# Transactional records
#
# Logging and history tracking

# %% [markdown]
# ## Real-World Example

# %% [raw]
# # Banking Transactions
#
# Each transaction = one row

# %% [raw]
# # Attendance System
#
# One row per student per day

# %% [markdown]
# ## Summary

# %% [raw]
# Row = single record
#
# Stored horizontally
#
# Contains values for all columns
#
# Manipulated using INSERT, SELECT, UPDATE, DELETE
#
# Core part of SQL operations
#
# Frequently tested in interviews

# %% [markdown]
# # Row Operations

# %% [markdown]
# ## Insert Row

# %% [raw]
# INSERT INTO employees VALUES (1, 'John', 50000);
#
# inserts values

# %% [markdown]
# ## Read Rows

# %% [raw]
# SELECT * FROM employees;
#
# read stored values

# %% [markdown]
# ## Filter Rows

# %% [raw]
# SELECT * FROM employees WHERE salary > 40000;
#
# filter values.

# %% [markdown]
# ## Update Row

# %% [raw]
# UPDATE employees SET salary = 55000 WHERE emp_id = 1;
#
# update existing values.

# %% [markdown]
# ## Delete Row

# %% [raw]
# DELETE FROM employees WHERE emp_id = 1;
#
# delete values.

# %% [markdown]
# ## Sort Rows

# %% [raw]
# SELECT * FROM employees ORDER BY salary DESC;
#
# sort values.

# %% [markdown]
# ## Limit Rows

# %% [raw]
# SELECT * FROM employees LIMIT 5;
#
# limit values views.

# %% [markdown]
# # Good to Know

# %% [markdown]
# ## Bulk Row Insertion

# %% [raw]
# INSERT INTO students VALUES
# (2, 'Bob', 21),
# (3, 'Charlie', 22);
#
# insert multiple values into a table.
# Used for loading initial data.

# %% [markdown]
# ## Insert Table Copy

# %% [raw]
# Using SELECT to Insert Rows
#
# INSERT INTO backup_students
# SELECT * FROM students;
#
# copy column values of one table into another table.
# used for migrating one table values into another table.

# %% [markdown]
# # Column

# %% [markdown]
# Columns are the attributes of the table or entity

# %%
A Column defines what kind of data a table can store.
It represents a single attribute of an entity.

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of a form:
#     field names -> Column
#     filled form -> row
# Without columns, rows would be meaningless values

# %% [markdown]
# ## Example

# %% [raw]
# | id                                   | name | age |
# | ------------------------------------ | ---- | --- |
# |                                      |      |     |
#
# This vertical part is a column.

# %% [markdown]
# ## HOW -

# %% [raw]
# Columns are defined when creating or altering a table.

# %% [markdown]
# ## Syntax

# %%
column_name data_type [constraints]

# %% [markdown]
# ## Example Query

# %% [raw]
# CREATE TABLE students (
#     id INT,
#     name VARCHAR(50),
#     age INT
# );

# %% [markdown]
# ## Real-World Example

# %% [raw]
# # Employee Database
#
# Columns: emp_id, name, salary, department

# %% [raw]
# # E-commerce
#
# SELECT product_name, price FROM products;

# %% [markdown]
# ## Summary

# %% [raw]
# Column = attribute of a table
#
# Stored vertically
#
# Has a defined data type
#
# Supports constraints
#
# Can be added, modified, or dropped
#
# Essential for data integrity

# %% [markdown]
# # Column Operation

# %% [markdown]
# ## Add Column

# %% [raw]
# ALTER TABLE students ADD email VARCHAR(100);
#
# add columns to an existing table.

# %% [markdown]
# ## Modify Column

# %% [raw]
# ALTER TABLE students MODIFY age INT;
#
# change data type of a column

# %% [markdown]
# ## Rename Column

# %% [raw]
# ALTER TABLE students RENAME COLUMN age TO student_age;
#
# rename column in a table.

# %% [markdown]
# ## Drop Column

# %% [raw]
# ALTER TABLE students DROP COLUMN email;
#
# drop a column from a table.

# %% [markdown]
# ## Set Default Value

# %% [raw]
# ALTER TABLE students ALTER age SET DEFAULT 18;
#
# set a predefined value for a column

# %% [markdown]
# ## Add Constraints to Column

# %% [raw]
# ALTER TABLE students ADD CONSTRAINT age_check CHECK (age >= 0);
#
# add conditions to a column.

# %% [markdown]
# # Good to Know

# %% [markdown]
# ## Computed / Derived Columns

# %% [raw]
# SELECT salary * 12 AS annual_salary FROM employees;
#
# summing annual salary.
# Used for reporting and analytics

# %% [markdown]
# ## JSON Columns

# %% [raw]
# CREATE TABLE users (
#     data JSON
# );
#
# used for semi-structured data.
# it has flexible schema.

# %% [markdown]
# # "ROW IS DATA; COLUMN IS STRUCTURE"

# %% [markdown]
# # Constraints

# %% [markdown]
# Constraints are rules applied on tables or columns to restrict invalid data.

# %% [raw]
# Constraints are rules applied on tables or columns to prevent invalid data from being inserted, updated or deleted.
# Constraints are automatically checked during INSERT or UPDATE.
# It is used to ensure data accuracy, consistency and reliability.

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of a college admission form:
#     Age must be >= 17
#     Email must be unique
#     Roll number cannot be empty.
# These rules are constraints that protect data quality.
#
# They act like guards that prevent wrong or invalid data from entering the table.

# %% [markdown]
# ## HOW-

# %% [raw]
# Constraints are defined:
#     During table creation(CREATE TABLE)
#     After creation(ALTER TABLE)

# %% [markdown]
# ## Syntax

# %% [raw]
# column_name data_type CONSTRAINT_TYPE

# %% [markdown]
# ## Example Query

# %% [raw]
# CREATE TABLE users (
#     id INT PRIMARY KEY,
#     email VARCHAR(100) UNIQUE,
#     age INT CHECK (age >= 18)
# );

# %% [markdown]
# ## When to Use

# %% [raw]
# Always in production databases
#
# Business-critical systems
#
# Financial and healthcare data

# %% [markdown]
# ## Real-World Example

# %% [raw]
# # Banking System
#
# Account number → UNIQUE
#
# Balance → CHECK (>= 0)

# %% [raw]
# # E-commerce
#
# Order → FOREIGN KEY to customer

# %% [markdown]
# ## Summary

# %% [raw]
# Constraints enforce rules
#
# Protect data integrity
#
# Applied at column or table level
#
# Types: NOT NULL, UNIQUE, PK, FK, CHECK, DEFAULT
#
# Reduce invalid data
#
# Essential for real-world databases

# %% [markdown]
# # Constraint Types

# %% [markdown]
# ## NOT NULL

# %% [raw]
# name VARCHAR(50) NOT NULL
#
# Prevents NULL values.

# %% [markdown]
# ## UNIQUE

# %% [raw]
# email VARCHAR(100) UNIQUE
#
# Prevents duplicate values.

# %% [markdown]
# ## PRIMARY KEY

# %% [raw]
# id INT PRIMARY KEY
#
# Combines NOT NULL + UNIQUE.
# One per table.

# %% [markdown]
# ## FOREIGN KEY

# %% [raw]
# FOREIGN KEY (dept_id) REFERENCES departments(id)
#
# Links tables together.

# %% [markdown]
# ## CHECK

# %% [raw]
# CHECK (salary > 0)
#
# Validates condition.

# %% [markdown]
# ## DEFAULT

# %% [raw]
# status VARCHAR(20) DEFAULT 'ACTIVE'
#
# Assigns default value.

# %% [markdown]
# ## Composite Constraint

# %% [raw]
# PRIMARY KEY (order_id, product_id)
#
# Multiple columns together.

# %% [markdown]
# ## FULL EXAMPLE

# %% [raw]
# CREATE TABLE employees (
#     emp_id INT PRIMARY KEY,
#     email VARCHAR(100) UNIQUE,
#     age INT CHECK (age >= 18),
#     dept_id INT,
#     status VARCHAR(20) DEFAULT 'ACTIVE',
#     FOREIGN KEY (dept_id) REFERENCES departments(id)
# );

# %% [markdown]
# # Good to know

# %% [markdown]
# ## Triggers

# %% [raw]
# CREATE TRIGGER check_age BEFORE INSERT ON users
# FOR EACH ROW
# BEGIN
#     IF NEW.age < 18 THEN SIGNAL SQLSTATE '45000';
# END;
#
# When to Use:
# Advanced rules

# %% [markdown]
# # Index

# %% [raw]
# An index in sql is a data structure that speeds up data retrieval from a database table.
# It is a separate data structure built on one or more columns and
# It stores column values + row pointers for fast retrieval of data.

# %% [raw]
# Instead of scanning the entire table row by row, the database uses an index to quickly locate the required data.

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of a book:
#     Book -> Table
#     Pages -> Rows
#     Index page -> SQL Index
# Without the index page, you must read the entire book to find a topic.
# With the index page, you jump directly to the page number.

# %% [markdown]
# ## HOW -

# %% [raw]
# Indexes work using data structure like:
#     B-Tree (most common)
#     Hash(limited cases)

# %% [markdown]
# ## Syntax

# %% [raw]
# CREATE INDEX index_name ON table_name(column_name);

# %% [markdown]
# ## Example Query

# %% [raw]
# CREATE INDEX idx_employee_name ON employees(name);

# %% [markdown]
# ## When to Use

# %% [raw]
# Large tables
#
# Frequently filtered columns
#
# Columns used in joins

# %% [markdown]
# ## Real-World Example

# %% [raw]
# # Banking System
#
# Index on account_number
# Query:
# CREATE UNIQUE INDEX idx_account ON accounts(account_number);

# %% [raw]
# # E-commerce Website
#
# Index on product_name and category

# %% [markdown]
# ## Summary

# %% [raw]
# Index speeds up SELECT queries
#
# Uses B-Tree structure
#
# Improves WHERE, JOIN, ORDER BY
#
# Costs storage and write performance
#
# Types: single, composite, unique, clustered
#
# Essential for large databases

# %% [markdown]
# # Index types

# %% [markdown]
# ## Single-Column Index

# %% [raw]
# CREATE INDEX idx_salary ON employees(salary);

# %% [markdown]
# ## Composite (Multi-Column) Index

# %% [raw]
# CREATE INDEX idx_name_dept ON employees(name, department);
#
# Used when filtering on multiple columns.

# %% [markdown]
# ## Unique Index

# %% [raw]
# CREATE UNIQUE INDEX idx_email ON users(email);
#
# Prevents duplicate values.

# %% [markdown]
# ## Primary Key Index

# %% [raw]
# PRIMARY KEY (id)
#
# Automatically created with PRIMARY KEY.

# %% [markdown]
# ## Clustered Index

# %% [raw]
# PRIMARY KEY (id)
#
# Data stored in index order.
# Only one per table.

# %% [markdown]
# ## Non-Clustered Index

# %% [raw]
# CREATE INDEX idx_city ON customers(city);
#
# Index separate from data
# Multiple allowed

# %% [markdown]
# ## Drop Index

# %% [raw]
# DROP INDEX idx_city;

# %% [markdown]
# ## Full Example with Index Operations

# %% [raw]
# CREATE INDEX idx_age ON students(age);
# CREATE UNIQUE INDEX idx_roll ON students(roll_no);
# DROP INDEX idx_age;

# %% [markdown]
# # Note

# %% [raw]
# Avoid using indexes on small tables and frequently updated columns as it trades extra storage and slow writes for
# faster reads of data from a database.

# %% [markdown]
# # Database Types

# %% [raw]
# RDBMS
# NoSQL
# In-Memory Database

# %% [markdown]
# # RDBMS - Relationsal DataBase Management System

# %% [raw]
# RBDMS is a database system that stores data in tables(relations), the tables are linked using primary and
# foreign keys and accessed using sql.

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of an Excel Workbook:
#     Workbook -> Database
#     Sheets -> Tables
#     Rows -> Records
#     Columns -> Attributes
# Relationships between sheets using IDs = RDBMS relationships.

# %% [markdown]
# ## Example

# %% [raw]
# MySQL
# PostgreSQL
# Oracle
# SQL Server

# %% [markdown]
# ## HOW-

# %% [raw]
# RDBMS works by:
#     Storing data in tables
#     Enforcing constraints
#     Using SQL for operations
#     Maintaining relationships using keys.

# %% [markdown]
# ## Syntax(Basic Flow)

# %% [raw]
# Application → SQL → RDBMS → Tables → Result

# %% [markdown]
# ## Example Query

# %% [raw]
# SELECT e.name, d.dept_name
# FROM employees e
# JOIN departments d
# ON e.dept_id = d.dept_id;

# %% [markdown]
# ## When to Use

# %% [raw]
# Banking systems
#
# ERP systems
#
# Transaction-heavy apps

# %% [markdown]
# ## Real-World Example

# %% [raw]
# # Banking System
#
# Accounts, transactions, customers
#
# Requires ACID

# %% [raw]
# # University Database
#
# Students ↔ Courses ↔ Professors

# %% [markdown]
# ## Summary

# %% [raw]
# RDBMS stores data in tables
#
# Uses SQL for querying
#
# Enforces relationships
#
# Supports ACID transactions
#
# Ensures data integrity
#
# Widely used in real-world apps

# %% [markdown]
# # RDBMS Concepts(Core)

# %% [raw]
# Tables & Relationships
# Normalization
# Constraints
# Transactions
# Indexes
# Views

# %% [markdown]
# # Nosql DB - Not Only SQL DB

# %% [raw]
# NoSQL stands for "Not Only SQL".
# Nosql is a non-relational database designed to store and manage large-scale, unstructured or semi-structured data with
# high performance and scalability.
# It does not rely on tables, rows and columns unlike RDBMS.

# %% [markdown]
# ## Example

# %% [raw]
# MongoDB
# Cassandra
# Redis
# DynamoDB

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of a wardrobe vs a suitcase:
#     RDBMS - Wardrobe with fixed shelves(strict structure)
#     NoSQL - Suitcase where items fit flexibly.
# NoSQL is flexible and fast when structure keeps changing.

# %% [markdown]
# ## HOW -

# %% [raw]
# NoSQL stores data in different models, not just tables.

# %% [markdown]
# ## Syntax(Basic Flow)

# %% [raw]
# Application → NoSQL DB → Distributed Storage → Result

# %% [markdown]
# ## Example Query

# %% [raw]
# db.users.insertOne({
#   name: "Alice",
#   age: 25,
#   skills: ["Python", "SQL"]
# })
#
# here,
# db.users - Collection name
# insertOne() - Insert operation
# JSON Object - Flexible document

# %% [markdown]
# ## When to Use

# %% [raw]
# Real-time applications
#
# Big data systems
#
# IoT and analytics
#
# Rapidly evolving schemas

# %% [markdown]
# ## Real-World Example

# %% [raw]
# # Social Media
#
# Posts, comments, likes (MongoDB)

# %% [raw]
# # IoT Systems
#
# Sensor data stored in NoSQL

# %% [markdown]
# ## Summary

# %% [raw]
# NoSQL = Not Only SQL
#
# Non-relational databases
#
# Flexible schema
#
# Horizontally scalable
#
# Types: Document, Key-Value, Column, Graph
#
# Used in big data and real-time apps

# %% [markdown]
# # Note

# %% [raw]
# NoSQL databases are built for scale, speed, and flexibility, making them ideal for modern,
# data-intensive applications.

# %% [markdown]
# # Nosql DB Types

# %% [markdown]
# ## Document-Based

# %% [raw]
# db.products.find({ price: { $gt: 1000 } })
#
# Stores JSON-like documents.
# Example: MongoDB

# %% [markdown]
# ## Key-Value Stores

# %% [raw]
# key = "user123"
# value = "{name:'John', age:30}"
#
# Stores key-value pairs.
# Example: Redis

# %% [markdown]
# ## Column-Family Stores

# %% [raw]
# RowKey | name | age
#
# Stores data in columns.
# Example: Cassandra

# %% [markdown]
# ## Graph Databases

# %% [raw]
# (User)-[FRIEND]->(User)
#
# Stores relationships.
# Example: Neo4j

# %% [markdown]
# ## Full Example(MongoDB CRUD)

# %% [raw]
# db.users.insertOne({ name: "Bob", age: 30 })
# db.users.find({ age: { $gt: 25 } })
# db.users.updateOne({ name: "Bob" }, { $set: { age: 31 } })
# db.users.deleteOne({ name: "Bob" })

# %% [markdown]
# # Good to Know

# %% [markdown]
# ## NewSQL

# %% [markdown]
# SQL + scalability
#
# Used for High-performance transactions

# %% [raw]
# It is a modern relational database that blend the best of traditional SQL databases (like ACID compliance,
# SQL interface) with the scalability of NoSQL systems.
# It offers high performance for online transaction processing (OLTP) without sacrificing data consistency.
# It is ideal for large-scale, real-time applications needing reliability.
#
# Example
# CockroachDB, NuoDB, VoltDB, Vitess, and YugabyteDB.

# %% [markdown]
# # In-Memory Db

# %% [raw]
# An In-Memory Database(IMDB) is a database that stores data directly in the system's RAM(memory) instead of on disk.
# Often used as cache or real-time store

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of studying from memory vs reading from a book:
#     Memory -> RAM(very fast)
#     Book -> Disk(slower)
# In-memory databases work like thinking instantly instead of searching pages.

# %% [markdown]
# ## Example

# %% [raw]
# Redis
# Memcached
# SAP HANA
# SingleStore (MemSQL)

# %% [markdown]
# ## HOW-

# %% [raw]
# IMDB works by:
#     Loading data into RAM
#     Processing queries directly in memory
#     Optionally persisting data to disk for durability or backup.

# %% [markdown]
# ## Syntax(Basic Flow)

# %% [raw]
# Application → RAM (IMDB) → Optional Disk Backup

# %% [markdown]
# ## Example Query

# %% [raw]
# SET user:1 "Alice"
# GET user:1
#
# here,
# SET user:1 "Alice" - Stores data in memory
# GET user:1 - Retrieves data

# %% [markdown]
# ## When to Use

# %% [raw]
# Caching
#
# Real-time analytics
#
# Session management
#
# Gaming and IoT

# %% [markdown]
# ## Real-World Example

# %% [raw]
# # E-commerce
#
# Cart data stored in Redis

# %% [raw]
# # Social Media
#
# Likes, sessions, counters

# %% [markdown]
# ## Summary

# %% [raw]
# In-memory DB stores data in RAM
#
# Extremely fast access
#
# Used for caching and real-time systems
#
# Examples: Redis, Memcached
#
# Limited by memory size
#
# Often combined with disk persistence

# %% [markdown]
# # SQL - Structured Query Language

# %% [raw]
# SQL is a query language used to interact with relational databases that are managed by RDBMS.
# It allow us to store, retrieve, update and manage data in databases.
# SQL - Query language
# RDBMS - Software system like mysql and so on.
#
# It is a declarative language meaning we tell the database what result(outcome) we want and not tell the step by step
# procedure to get the outcome.
# It is the foundation of data handling in almost every data-driven application.

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of SQL as English for databases:
#     You ask questions -> SQL queries
#     Databases responds -> Query results
# Just like English helps humans communicate, SQL helps humans to communicate with databases.

# %% [markdown]
# ## Example

# %% [raw]
# Used in:
#     MySQL
#     PostgreSQL
#     Oracle
#     SQL Server

# %% [markdown]
# ## HOW -

# %% [raw]
# SQL works by sending commands(queries) to the database.

# %% [markdown]
# ## Syntax(Basic Flow)

# %% [raw]
# User → SQL Query → DBMS → Database → Result
#
# Basic Syntax:
#
# SELECT column_name
# FROM table_name
# WHERE condition;

# %% [markdown]
# ## Example Query

# %% [raw]
# SELECT name, salary
# FROM employees
# WHERE salary > 50000;

# %% [markdown]
# ## When to Use

# %% [raw]
# Any relational database
#
# Data analysis
#
# Backend systems

# %% [markdown]
# ## Real-World Example

# %% [raw]
# # Banking System
#
# SELECT * FROM transactions WHERE account_id = 101;

# %% [raw]
# # Data Analytics
#
# SELECT department, AVG(salary)
# FROM employees
# GROUP BY department;

# %% [markdown]
# ## Summary

# %% [raw]
# SQL = Structured Query Language
#
# Used with RDBMS
#
# Declarative language
#
# Supports DDL, DML, DQL, DCL, TCL
#
# Essential for data professionals
#
# Widely used in industry

# %% [markdown]
# # Facts

# %% [raw]
# Even though SQL is declarative, the database still executes procedural steps internally.
#
# SQL Query
#    ↓
# Parser
#    ↓
# Optimizer
#    ↓
# Execution Plan
#    ↓
# Results
#
# The query optimizer decides:
#     Use index or not
#     Join order
#     Join type
#     Parallelism
# You never control this directly.

# %% [markdown]
# # Is SQL purely declarative?

# %% [raw]
# Not fully.
# SQL has procedural extensions:
#     PL/SQL (Oracle)
#     T-SQL (SQL Server)
#     Stored procedures
#     Triggers

# %% [markdown]
# ## Example

# %% [raw]
# IF salary > 60000 THEN
#    UPDATE bonus = 10000;
# END IF;

# %% [raw]
# So,
# SQL core = declarative
# Extensions = procedural

# %% [markdown]
# ## Analogy

# %% [raw]
# # Restaurant
# You: “I want a pizza” (WHAT)
# Chef decides how to cook (HOW)
#
# You don’t tell:
#     How much heat
#     Cooking time
#     Order of steps

# %% [markdown]
# # SQL Command Types

# %% [raw]
# DDL (Data Definition Language)
# DML (Data Manipulation Language)
# DQL (Data Query Language)
# DCL (Data Control Language)
# TCL (Transaction Control Language)

# %% [markdown]
# # DDL - Data Definition Language

# %% [raw]
# DDL is a set of SQL commands used to define and manage the structure of a database.
# It deals with tables, columns, databases, schema rules.
# DDL does not work with actual data, it works with structure only.
#
# Think of DDL as a architect's blueprint of a building:
#     Before people live inside(data),
#     You must design rooms, walls, doors(tables, columns, constraints)
#
# MAIN DML COMMANDS:
#     CREATE
#     ALTER
#     DROP
#     TRUNCATE
#     RENAME

# %% [markdown]
# ## Without

# %% [raw]
# No DDL, No Database
# Without DDL:
#     No tables
#     No columns
#     No database design

# %% [markdown]
# ## Analogy

# %% [raw]
# DDL is like designing a house
#     CREATE - Build the house
#     ALTER - Add a room or window
#     DROP - Demolish the house
#     TRUNCATE - Empty the house but keep it standing.

# %% [markdown]
# ## How-

# %% [raw]
# DDL works on metadata
# It is auto-committed(Cannot rollback easily)
# Changes are permanent

# %% [markdown]
# ## Syntax

# %% [raw]
# CREATE TABLE table_name (...);

# %% [markdown]
# ## Example Query

# %% [raw]
# CREATE TABLE employees (
#     id INT,
#     name VARCHAR(50),
#     salary INT
# );

# %% [markdown]
# ## When to Use

# %% [raw]
# Initial database setup
#
# Schema changes
#
# Structural cleanup

# %% [markdown]
# ## Real-World Example

# %% [markdown]
# ### 🏢 Company Setup

# %% [raw]
# CREATE TABLE departments (
#     dept_id INT,
#     dept_name VARCHAR(50)
# );
#
# Used during:
#     ERP setup
#     HR systems

# %% [markdown]
# ### 🏥 Hospital Update

# %% [raw]
# ALTER TABLE patients ADD blood_group VARCHAR(5);
#
# Used when:
# New medical requirement added

# %% [markdown]
# ### 🧹 Log Cleanup

# %% [raw]
# TRUNCATE TABLE logs;
#
# Used when:
#     Logs become huge
#     Data not needed

# %% [markdown]
# ## Summary

# %% [raw]
# DDL = Data Definition Language
#
# Works on structure
#
# Auto-committed
#
# Commands: CREATE, ALTER, DROP, TRUNCATE, RENAME
#
# Powerful and irreversible
#
# Foundation of databases

# %% [raw]
# "DDL works on structure, not on actual data"
# DDL = Blueprint; DML = daily usage.

# %% [markdown]
# # All Operations of DDL

# %% [raw]
# | Command  | Purpose          |
# | -------- | ---------------- |
# | CREATE   | Create object    |
# | ALTER    | Modify structure |
# | DROP     | Delete object    |
# | TRUNCATE | Remove all rows  |
# | RENAME   | Rename object    |

# %% [markdown]
# ## 1️⃣ CREATE

# %% [raw]
# CREATE TABLE students (
#     id INT,
#     name VARCHAR(30)
# );
#
# Creates tables/databases

# %% [markdown]
# ## 2️⃣ ALTER

# %% [raw]
# ALTER TABLE students ADD age INT;
#
# Modify structure

# %% [markdown]
# ## 3️⃣ DROP

# %% [raw]
# DROP TABLE students;
#
# Deletes structure + data

# %% [markdown]
# ## 4️⃣ TRUNCATE

# %% [raw]
# TRUNCATE TABLE students;
#
# Deletes only data

# %% [markdown]
# ## 5️⃣ RENAME

# %% [raw]
# RENAME TABLE students TO learners;
#
# Renames table

# %% [markdown]
# ## All Operations Combined

# %% [raw]
# CREATE TABLE demo (id INT);
# ALTER TABLE demo ADD name VARCHAR(20);
# TRUNCATE TABLE demo;
# RENAME TABLE demo TO demo_new;
# DROP TABLE demo_new;

# %% [markdown]
# # DML - Data Manipulation Language

# %% [raw]
# DML is a set of SQL commands used to manipulate rows(records) in a table.
# It is used to insert new data, update existing data, deleting data and reading data in a table.
#
# Main DML commands:
#     INSERT - Add data
#     UPDATE - Modify data
#     DELETE - Remove data
#     SELECT - Read data(part of DQL, But commonly taught under DML)

# %% [markdown]
# ## Without

# %% [raw]
# Tables exist but stay empty
# No reports, No analytics, No applications
# Data becomes read-only structure

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of a database table as a notebook:
#     DDL creates the notebook
#     DML is writing, editing, erasing and reading pages in that notebook.
# Without DML, the notebook exists but you can't write anything in it.

# %% [markdown]
# ## HOW -

# %% [raw]
# DML commands operates row by row.
# Changes can be committed or rolled back.
# Works inside transactions.

# %% [markdown]
# ## Syntax

# %% [raw]
# INSERT INTO table_name VALUES (...);
# UPDATE table_name SET column = value WHERE condition;
# DELETE FROM table_name WHERE condition;
# SELECT * FROM table_name;

# %% [markdown]
# ## Example Query

# %% [raw]
# INSERT INTO employees VALUES (1, 'Arun', 'IT', 50000);

# %% [markdown]
# ## When to Use

# %% [raw]
# CRUD operations
#
# Reporting
#
# User-driven applications

# %% [markdown]
# ## Real-World Example

# %% [markdown]
# ### 🏦 Banking System

# %% [raw]
# UPDATE accounts SET balance = balance - 500 WHERE acc_no = 101;
#
# Used during money withdrawal

# %% [markdown]
# ### 🛒 E-commerce

# %% [raw]
# INSERT INTO orders VALUES (5001, 101, 'Laptop');
#
# New order placed

# %% [markdown]
# ### HR Management

# %% [raw]
# SELECT * FROM employees WHERE department = 'IT';
#
# Employee reporting

# %% [markdown]
# ## Summary

# %% [raw]
# DML manipulates table data
#
# Core commands: INSERT, SELECT, UPDATE, DELETE
#
# Supports transactions
#
# Dangerous without WHERE
#
# Backbone of real-world SQL usage

# %% [markdown]
# # All Operations of DML

# %% [raw]
# | Command | Purpose     |
# | ------- | ----------- |
# | INSERT  | Add data    |
# | SELECT  | Read data   |
# | UPDATE  | Modify data |
# | DELETE  | Remove data |

# %% [raw]
# -- INSERT
# INSERT INTO students VALUES (101, 'Amit', 85);
#
# -- SELECT
# SELECT name, marks FROM students;
#
# -- UPDATE
# UPDATE students SET marks = 90 WHERE id = 101;
#
# -- DELETE
# DELETE FROM students WHERE id = 101;

# %% [markdown]
# # DQL - Data Query Language

# %% [raw]
# DQL is used to retreive data from a database without changing it.
#
# Main Command:
#     SELECT

# %% [markdown]
# ## Without

# %% [raw]
# Data exists in tables
# But you cannot view or analyze it
# Database becomes a locked box

# %% [markdown]
# ## Analogy

# %% [raw]
# Imagine a library:
#     Books - Data
#     Shelves - Tables
#     DQL - Asking the librarian questions
# You are only reading, not writing or tearing pages.

# %% [markdown]
# ## HOW -

# %% [raw]
# Reads data from tables
# Does not modify data
# Can filter, sort, group and aggregate results

# %% [markdown]
# ## Syntax

# %% [raw]
# SELECT column1, column2
# FROM table_name
# WHERE condition;

# %% [markdown]
# ## Example Query

# %% [raw]
# SELECT name, salary
# FROM employees
# WHERE salary > 30000;

# %% [markdown]
# ## When to Use

# %% [raw]
# Reports
#
# Dashboards
#
# Data analysis
#
# Debugging data issues

# %% [markdown]
# ## Real-World Example

# %% [markdown]
# ### HR Dashboard

# %% [raw]
# SELECT department, COUNT(*) FROM employees GROUP BY department;
#
# Shows employee count per department

# %% [markdown]
# ### Banking Reports

# %% [raw]
# SELECT * FROM transactions WHERE amount > 100000;
#
# Detects large transactions

# %% [markdown]
# ### E-commerce Analytics

# %% [raw]
# SELECT product_id, SUM(quantity)
# FROM orders
# GROUP BY product_id;
#
# Finds best-selling products

# %% [markdown]
# ## Summary

# %% [raw]
# DQL = Data Query Language
#
# Main command: SELECT
#
# Used for reading & analyzing data
#
# Safe and non-destructive
#
# Backbone of reporting systems

# %% [markdown]
# # All Operations

# %% [markdown]
# ## DQL Operations (Clauses)

# %% [raw]
# | Clause   | Purpose         |
# | -------- | --------------- |
# | SELECT   | Choose columns  |
# | FROM     | Choose table    |
# | WHERE    | Filter rows     |
# | ORDER BY | Sort results    |
# | GROUP BY | Group rows      |
# | HAVING   | Filter groups   |
# | LIMIT    | Restrict output |

# %% [markdown]
# ## Query Using All DQL Clauses

# %% [raw]
# SELECT department, COUNT(*) AS emp_count
# FROM employees
# WHERE salary > 30000
# GROUP BY department
# HAVING COUNT(*) > 2
# ORDER BY emp_count DESC
# LIMIT 5;

# %% [markdown]
# # DCL - Data Control Language

# %% [raw]
# DCL is used to control access and permissions in a database.
# It decides who can access data and what actions they can perform.
#
# Main DCL commands:
#     GRANT
#     REVOKE

# %% [markdown]
# ## Without

# %% [raw]
# Everyone gets full access
# High risk of data deletion
# No security or control
# Violates compliance rules

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of a company building:
#     Rooms - Tables
#     Employees - Users
#     DCL - Security guards & access cards
# Some people can enter, some can edit, some can only view.

# %% [markdown]
# ## HOW -

# %% [raw]
# DCL assigns permissions to users or roles
# Control operations like SELECT, INSERT, UPDATE, DELETE
# Works at table, database, or column level.

# %% [markdown]
# ## Syntax

# %% [raw]
# GRANT permission ON object TO user;
# REVOKE permission ON object FROM user;

# %% [markdown]
# ## Example Query

# %% [raw]
# GRANT SELECT, INSERT ON employees TO analyst; # grants permissions to analyst to read & add access
# REVOKE INSERT ON employees FROM analyst; # removes data insertion permissions from analyst

# %% [markdown]
# ## When to Use

# %% [raw]
# Multi-user databases
#
# Production environments
#
# Compliance & security systems

# %% [markdown]
# ## Real-World Example

# %% [markdown]
# ### Data Analyst Access

# %% [raw]
# GRANT SELECT ON sales TO analyst;
#
# Analyst can view reports only

# %% [markdown]
# ### HR System

# %% [raw]
# GRANT SELECT, UPDATE ON employees TO hr_user;
#
# HR can update employee records

# %% [markdown]
# ### Production Safety

# %% [raw]
# REVOKE DELETE ON orders FROM intern;
#
# Prevents accidental data loss

# %% [markdown]
# ## Summary

# %% [raw]
# DCL = Data Control Language
#
# Controls access & permissions
#
# Key commands: GRANT, REVOKE
#
# Improves security
#
# Mandatory in multi-user DBs

# %% [markdown]
# # All Operations of DCL

# %% [raw]
# | Command | Purpose            |
# | ------- | ------------------ |
# | GRANT   | Give permissions   |
# | REVOKE  | Remove permissions |
#
# Permissions include:
#     SELECT
#     INSERT
#     UPDATE
#     DELETE
#     ALL

# %% [markdown]
# ## Working Code with DCL Operations

# %% [raw]
# -- Grant read access
# GRANT SELECT ON orders TO user1;
#
# -- Grant full access
# GRANT ALL ON customers TO admin;
#
# -- Revoke delete permission
# REVOKE DELETE ON customers FROM user1;

# %% [markdown]
# ## CREATE USER

# %% [raw]
# create user 'student_user'@'localhost' identified by 'password123';

# %% [markdown]
# ## Delete User

# %% [raw]
# drop user 'student_user'@'localhost';
#
# Condition:
#
# drop user if exists 'student_user'@'localhost';

# %% [markdown]
# ## Check User existence

# %% [raw]
# select user, host from mysql.user;

# %% [markdown]
# # Good To Know

# %% [markdown]
# ## Roles

# %% [markdown]
# ## Create Role

# %% [raw]
# CREATE ROLE read_only;
# GRANT SELECT ON employees TO read_only;
# GRANT read_only TO user2;
#
# When to Use:
#     Large organizations

# %% [markdown]
# ## Delete Role

# %% [raw]
# drop role analyst_role;

# %% [markdown]
# ## Remove Role from an User

# %% [raw]
# REVOKE analyst_role FROM 'user1'@'localhost';

# %% [markdown]
# ## If role was set as default, You may also want to remove it from default roles:

# %% [raw]
# SET DEFAULT ROLE NONE TO 'user1'@'localhost';

# %% [markdown]
# ## Roles are not active by default in mysql(8+ only), so we need to activate it.

# %% [markdown]
# ## Main session

# %% [raw]
# SET DEFAULT ROLE student_role TO 'student_user'@'localhost';

# %% [markdown]
# ## User session

# %% [raw]
# set role student_role;

# %% [markdown]
# ## Check Role Grants/privileges

# %% [raw]
# SHOW GRANTS FOR student_role;

# %% [markdown]
# ## Check User Grants

# %% [raw]
# SHOW GRANTS FOR 'student_user'@'localhost';

# %% [markdown]
# # TCL - Transaction Control Language

# %% [raw]
# TCL is used to manage transactions, meaning it controls when changes are saved permanently or undone.
#
# Main TCL commands:
#     COMMIT
#     ROLLBACK
#     SAVEPOINT

# %% [markdown]
# ## Without

# %% [raw]
# Every change becomes permanent instantly
# No undo option
# High risk of data corruption
# System failure cause inconsistent data

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of shopping online:
#     Adding items to cart -> Changes not final
#     Clicking "Pay Now" -> Changes saved
#     Clicking "Cancel" -> Changes undone
# TCL is the Pay(commit)/Cancel(rollback)/Checkpoint(savepoint) system for databases.

# %% [markdown]
# ## HOW -

# %% [raw]
# Groups multiple SQL statements into a transaction
# Allows undo until committed
# Works closely with ACID properties

# %% [markdown]
# ## Syntax

# %% [raw]
# COMMIT;
# ROLLBACK;
# SAVEPOINT savepoint_name;

# %% [markdown]
# ## Example Query

# %% [raw]
# BEGIN; # starts a transaction
#
# UPDATE accounts SET balance = balance - 500 WHERE acc_no = 101; # Modifies balances
# UPDATE accounts SET balance = balance + 500 WHERE acc_no = 102;
#
# SAVEPOINT transfer_done; # Creates a checkpoint
#
# COMMIT; # Saves changes permanently

# %% [markdown]
# ## When to Use

# %% [raw]
# Financial transactions
#
# Multi-step updates
#
# Critical operations

# %% [markdown]
# ## Real-World Example

# %% [markdown]
# ### Bank Transfer

# %% [raw]
# UPDATE accounts SET balance = balance - 1000 WHERE acc_no = 1;
# UPDATE accounts SET balance = balance + 1000 WHERE acc_no = 2;
# COMMIT;
#
# Ensures atomic transfer

# %% [markdown]
# ### Order Processing

# %% [raw]
# INSERT INTO orders VALUES (101, 'Phone');
# ROLLBACK;
#
# Cancels failed order

# %% [markdown]
# ### Inventory Update

# %% [raw]
# SAVEPOINT stock_update;
#
# Partial safety during bulk updates

# %% [markdown]
# ## Summary

# %% [raw]
# TCL = Transaction Control Language
#
# Manages commits and rollbacks
#
# Prevents data inconsistency
#
# Works with ACID properties
#
# Essential for critical systems

# %% [markdown]
# # All Operations of TCL

# %% [raw]
# | Command   | Purpose           |
# | --------- | ----------------- |
# | COMMIT    | Save changes      |
# | ROLLBACK  | Undo changes      |
# | SAVEPOINT | Create checkpoint |

# %% [markdown]
# ## Working Code with All TCL Operations

# %% [raw]
# BEGIN;
#
# INSERT INTO orders VALUES (1, 'Laptop');
# SAVEPOINT order_added;
#
# DELETE FROM orders WHERE id = 1;
# ROLLBACK TO order_added;
#
# COMMIT;

# %% [markdown]
# ## Disable AutoCommit

# %% [raw]
# SET autocommit = 0;

# %% [markdown]
# ## Enable AutoCommit

# %% [raw]
# SET autocommit = 1

# %% [markdown]
# ## Rollback

# %% [raw]
# begin;
# delete....;
# rollback;
# commit;

# %% [markdown]
# ## Rollback to savepoint

# %% [raw]
# begin;
# insert....;
# savepoint savepoint_name;
# delete....;
# rollback to savepoint_name;
# commit;

# %% [markdown]
# # Keys

# %% [raw]
# Keys are columns or combination of columns that uniquely identifies rows and create relationships between tables
# in a database.

# %% [markdown]
# ## Without

# %% [raw]
# Duplicate records
# Broken relationships
# Incorrect reports
# Data inconsistency

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of a school:
#     Student name -> Can repeat
#     Roll number -> unique
# Keys are like roll numbers, they uniquely identify records.

# %% [markdown]
# ## HOW -

# %% [raw]
# Defined during table creation
# Enforced by database engine
# Automatically prevent invalid data.

# %% [markdown]
# ## Syntax

# %% [raw]
# CREATE TABLE students (
#   id INT PRIMARY KEY,
#   email VARCHAR(100) UNIQUE
# );

# %% [markdown]
# ## Example Query

# %% [raw]
# CREATE TABLE orders (
#   order_id INT PRIMARY KEY,
#   customer_id INT,
#   FOREIGN KEY (customer_id) REFERENCES customers(customer_id)
# );

# %% [markdown]
# ## When to Use

# %% [raw]
# Every relational database
#
# Multi-table systems
#
# Production environments

# %% [markdown]
# ## Real-World Example

# %% [markdown]
# ### Banking System

# %% [raw]
# account_number PRIMARY KEY
#
# Identifies bank accounts uniquely

# %% [markdown]
# ### E-commerce

# %% [raw]
# FOREIGN KEY (user_id) REFERENCES users(id)
#
# Links orders to users

# %% [markdown]
# ### College Database

# %% [raw]
# PRIMARY KEY (student_id, subject_id)
#
# Tracks enrollments

# %% [markdown]
# ## Summary

# %% [raw]
# Keys identify rows uniquely
#
# Primary key = main identifier
#
# Foreign key = relationship builder
#
# Composite keys use multiple columns
#
# Keys are mandatory for RDBMS design

# %% [markdown]
# # Key Types

# %% [raw]
# | Key Type      | Purpose               |
# | ------------- | --------------------- |
# | Primary Key   | Unique row identifier |
# | Foreign Key   | Connects tables       |
# | Candidate Key | Possible primary keys |
# | Super Key     | Any unique identifier |
# | Composite Key | Multiple columns      |
# | Unique Key    | Prevent duplicates    |
# | Natural Key   | Real-world identifier |
# | Surrogate Key | Artificial ID         |

# %% [raw]
# CREATE TABLE users (
#   user_id INT PRIMARY KEY,
#   email VARCHAR(100) UNIQUE,
#   phone VARCHAR(15),
#   username VARCHAR(50),
#   UNIQUE (phone, username)
# );

# %% [markdown]
# # Primary Key

# %% [raw]
# A Primary key is a column or combination of columns that uniquely identifies each row in a table.
# It cannot be NULL and only one per table.
#
# It can be single column(id).
# It can be multiple column(composite primary key)

# %% [markdown]
# ## Without

# %% [raw]
# Duplicate records
# Difficult update/deletes
# Foreign keys cannot reference properly
# Data integrity breaks

# %% [markdown]
# ## Analogy

# %% [raw]
# Think of an Aadhaar number/Roll number:
#     Names can repeat
#     Addresses can change
#     Aadhar number is unique
# A primary key is the aadhaar number of a table.

# %% [markdown]
# ## HOW -

# %% [raw]
# Enforced by the database engine
# Automatically creates a unique index
# Rejects duplicate or NULL values

# %% [markdown]
# ## Syntax

# %% [raw]
# PRIMARY KEY (column_name)

# %% [markdown]
# ## Example Query

# %% [raw]
# CREATE TABLE students (
#   student_id INT PRIMARY KEY,
#   name VARCHAR(50),
#   email VARCHAR(100)
# );

# %% [markdown]
# ## 📌When to Use

# %% [raw]
# Every relational table
#
# Frequently queried tables
#
# Relationship-based databases

# %% [markdown]
# ## Real-World Example

# %% [markdown]
# ### Banking

# %% [raw]
# account_number PRIMARY KEY
#
# Identifies accounts uniquely

# %% [markdown]
# ### E-commerce Orders

# %% [raw]
# order_id PRIMARY KEY
#
# Tracks orders

# %% [markdown]
# ### College Enrollment

# %% [raw]
# PRIMARY KEY (student_id, subject_id)
#
# Prevents duplicate enrollments

# %% [markdown]
# ## Summary

# %% [raw]
# Primary key = unique identifier
#
# No NULLs allowed
#
# One per table
#
# Can be composite
#
# Automatically indexed

# %% [markdown]
# # Ways to Define a Primary Key

# %% [markdown]
# ## M1: Column-Level Primary Key (Single Column)

# %% [raw]
# Primary key defined next to the column.

# %% [markdown]
# ### Example

# %% [raw]
# CREATE TABLE students (
#   student_id INT PRIMARY KEY,
#   name VARCHAR(50)
# );
#
# 📌Use when: One column uniquely identifies rows.

# %% [markdown]
# ## M2: Table-Level Primary Key (Single Column)

# %% [raw]
# Primary key defined after all columns.

# %% [markdown]
# ### Example

# %% [raw]
# CREATE TABLE students (
#   student_id INT,
#   name VARCHAR(50),
#   PRIMARY KEY (student_id)
# );
#
# 📌Use when: You want cleaner or more flexible design.

# %% [markdown]
# ## M4: Composite Primary Key (Multiple Columns)

# %% [raw]
# Uses combination of columns to ensure uniqueness.Join tables for keys

# %% [markdown]
# ### Example

# %% [raw]
# CREATE TABLE enrollments (
#   student_id INT,
#   course_id INT,
#   PRIMARY KEY (student_id, course_id)
# );
#
# 📌 Use when: No single column is unique.

# %% [markdown]
# ## M4: Primary Key Using ALTER TABLE

# %% [raw]
# Primary key added after table creation.

# %% [markdown]
# ### Example

# %% [raw]
# ALTER TABLE students
# ADD PRIMARY KEY (student_id);
#
# 📌 Use when: Table already exists.

# %% [markdown]
# ## Working Code with All Methods

# %% [raw]
# CREATE TABLE orders (
#   order_id INT,
#   product_id INT,
#   PRIMARY KEY (order_id, product_id)
# );
#
# ALTER TABLE customers
# ADD PRIMARY KEY (customer_id);

# %% [markdown]
# # Foreign Key

# %% [raw]
# A Foreign key(FK) is a column or group of columns of one table that refers to the primary key of another table
# It is used to establish relationships between tables.

# %% [markdown]
# ## Without

# %% [raw]
# Orders can exist without customers
# Students can enroll in non-existent courses
# Data becomes unreliable and messy.

# %% [markdown]
# ## 🧠Analogy

# %% [raw]
# Think of a foreign key like a child's school id card:
#     The school already exists(parent table)
#     The id card must refer to a valid school
#     You cannot issue an ID for a non-existent school
# Similarly, a foreign key ensures a record must refer to an existing record in another table.

# %% [markdown]
# ## HOW -

# %% [raw]
# Parent table - Has primary key
# Child table - Has foreign key
# Database checks:
#     Insert -> parent record exists?
#     Update/Delete -> allowed or restricted?

# %% [markdown]
# ## Syntax

# %% [raw]
# FOREIGN KEY (column_name)
# REFERENCES parent_table(primary_key)

# %% [markdown]
# ## Example Query

# %% [raw]
# CREATE TABLE customers(
#     customer_id INT PRIMARY KEY,
#     name VARCHAR(50)
# );
#
# CREATE TABLE orders(
#     order_id INT PRIMARY KEY,
#     customer_id INT,
#     FOREIGN KEY (customer_id) REFERENCES customers(customer_id)
# );

# %% [markdown]
# ## 📌When to Use

# %% [raw]
# ✔ When tables are related
# ✔ When data accuracy matters
# ✔ In normalized databases

# %% [markdown]
# ## Real-World Example

# %% [markdown]
# ### E-commerce

# %% [raw]
# orders.customer_id → customers.customer_id
#
# Ensures every order belongs to a valid customer.

# %% [markdown]
# ### University System

# %% [raw]
# enrollments.student_id → students.student_id
#
# Prevents enrollment of fake students.

# %% [markdown]
# ### Banking

# %% [raw]
# transactions.account_id → accounts.account_id
#
# Guarantees valid accounts.

# %% [markdown]
# ## Summary

# %% [raw]
# Foreign Key links tables
#
# Refers to Primary Key
#
# Prevents invalid data
#
# Supports normalization
#
# Can cascade updates/deletes
#
# Essential for RDBMS integrity

# %% [markdown]
# # All Ways to Define Foreign Key

# %% [markdown]
# ## M1: Column-Level Foreign Key (Inline)

# %% [raw]
# Defined inside the column definition.

# %% [markdown]
# ### Example Query

# %% [raw]
# CREATE TABLE orders (
#     order_id INT PRIMARY KEY,
#     customer_id INT REFERENCES customers(customer_id)
# );

# %% [markdown]
# ## M2: Table-Level Foreign Key (Recommended)

# %% [raw]
# Defined after all columns.

# %% [markdown]
# ### Example Query

# %% [raw]
# CREATE TABLE orders (
#     order_id INT PRIMARY KEY,
#     customer_id INT,
#     FOREIGN KEY (customer_id) REFERENCES customers(customer_id)
# );

# %% [markdown]
# ## M3: Composite Foreign Key (Multiple Columns)

# %% [markdown]
# ### Example Query

# %% [raw]
# FOREIGN KEY (order_id, product_id)
# REFERENCES order_items(order_id, product_id)

# %% [markdown]
# ## M4: Foreign Key Using ALTER TABLE

# %% [raw]
# Used after table creation.

# %% [markdown]
# ### Example Query

# %% [raw]
# ALTER TABLE orders
# ADD CONSTRAINT fk_customer
# FOREIGN KEY (customer_id)
# REFERENCES customers(customer_id);

# %% [markdown]
# ## M5: Foreign Key with ON DELETE / ON UPDATE

# %% [raw]
# Deletes/updates child rows automatically

# %% [markdown]
# ### Example Query

# %% [raw]
# FOREIGN KEY (customer_id)
# REFERENCES customers(customer_id)
# ON DELETE CASCADE
# ON UPDATE CASCADE

# %% [markdown]
# ## M6: Named Foreign Key Constraint

# %% [markdown]
# ### Example Query

# %% [raw]
# CONSTRAINT fk_orders_customers
# FOREIGN KEY (customer_id)
# REFERENCES customers(customer_id)

# %% [markdown]
# ## M7: Self-Referencing Foreign Key

# %% [markdown]
# ### Example Query

# %% [raw]
# FOREIGN KEY (manager_id)
# REFERENCES employees(employee_id)
#
# Used in:
#     Employee hierarchy
#     Category trees

# %% [markdown]
# # Foreign Key Actions

# %% [raw]
# | Action               | Meaning                         |
# | -------------------- | ------------------------------- |
# | `ON DELETE CASCADE`  | Delete child rows automatically |
# | `ON DELETE SET NULL` | Set FK to NULL                  |
# | `ON DELETE RESTRICT` | Block delete                    |
# | `ON UPDATE CASCADE`  | Update child rows               |

# %% [markdown]
# ## ON DELETE NO ACTION

# %% [raw]
# Similar to RESTRICT (default behavior).
#
# Behavior:
#     Checks constraint at end of statement
#     Delete fails if child exists

# %% [markdown]
# ### Example Query

# %% [raw]
# ON DELETE NO ACTION

# %% [markdown]
# ## ON DELETE SET DEFAULT

# %% [raw]
# Sets FK to default value.

# %% [markdown]
# ### Example Query

# %% [raw]
# ON DELETE SET DEFAULT
#
# Eg:
# Default customer_id = 0

# %% [markdown]
# ## All-in-One Example

# %% [raw]
# FOREIGN KEY (customer_id)
# REFERENCES customers(customer_id)
# ON DELETE CASCADE
# ON UPDATE CASCADE;

# %% [markdown]
# # Candidate key

# %% [markdown]
# # Super key

# %% [markdown]
# # Composite key

# %% [markdown]
# # Unique key

# %% [markdown]
# # Natural key

# %% [markdown]
# # Surrogate key

# %% [markdown]
# # SQL Execution Order
